# %% [markdown]
# <a href="https://colab.research.google.com/github/Estefanoooo/Quimica_practicas/blob/main/Electroquimica/PC_Electroquimica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Enunciado
# Tema: Semireacciones

"""input: ingresar los reactivos y productos

           reactivos = A, B

           productos = A*, B**

output: imprimir las semireacciones

           reducción: A* + *e- -> A

           oxidacion: B -> B** + **e-

ojo: los electrones deben ser calculados por la diferencia en los estados de oxidación"""

# %%
pip install chempy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.4/210.4 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 84.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.2/242.2 kB 26.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 12.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.6 MB/s eta 0:00:00
# ...
#   Created wheel for pyneqsys: filename=pyneqsys-0.5.7-py2.py3-none-any.whl size=27264 sha256=1388651fd2b1c27980e28cf99a3b508970665488903fe86cebdd1d79ba704906
#   Stored in directory: /root/.cache/pip/wheels/63/9e/0f/f0e239f188774c6772dd98f3979e5aa53af04922d8411b9f13
# ...
#   Created wheel for pyodesys: filename=pyodesys-0.14.2-py2.py3-none-any.whl size=126195 sha256=1c240d357ea3e1f7d67dd66cd38db5773f467c504375dfc74da3757602d550be
# ...

# %%
from chempy import balance_stoichiometry

def ingresar_elemento():
    elemento = input("Ingrese un elemento (o 'fin' para terminar): ")
    if elemento.lower() == 'fin':
        return None
    estado_oxidacion = input(f"Ingrese el estado de oxidación para {elemento}: ")
    return f"{elemento}^{{{estado_oxidacion}}}"

def obtener_lista_elementos():
    lista_elementos = []

    while True:
        elemento = ingresar_elemento()

        if elemento is None:
            break

        lista_elementos.append(elemento)

    return lista_elementos

# Obtener reactantes
print("Ingrese los reactantes (ingrese 'fin' para terminar):")
reactantes = obtener_lista_elementos()

# Obtener productos
print("Ingrese los productos (ingrese 'fin' para terminar):")
productos = obtener_lista_elementos()

# Mostrar resultados
print("\nReactantes:", " + ".join(reactantes))
print("Productos:", " + ".join(productos))

# Identificar cambios de estado de oxidación
cambios_estado_oxidacion = []

for i in range(min(len(reactantes), len(productos))):
    reactante = reactantes[i]
    producto = productos[i]

    if reactante != producto:
        cambio = f"reducción: {reactante} + e- -> {producto}"
        cambios_estado_oxidacion.append(cambio)

print("\nSemirreacciones de oxidación y reducción:")
for cambio in cambios_estado_oxidacion:
    print(cambio)
# Out:
# Ingrese los reactantes (ingrese 'fin' para terminar):
# Ingrese un elemento (o 'fin' para terminar): Al
# Ingrese el estado de oxidación para Al: 3
# Ingrese un elemento (o 'fin' para terminar): Cu
# Ingrese el estado de oxidación para Cu: 1
# Ingrese un elemento (o 'fin' para terminar): fin
# Ingrese los productos (ingrese 'fin' para terminar):
# Ingrese un elemento (o 'fin' para terminar): Al
# Ingrese el estado de oxidación para Al: 1
# Ingrese un elemento (o 'fin' para terminar): Cu
# Ingrese el estado de oxidación para Cu: 3
# Ingrese un elemento (o 'fin' para terminar): fin
#
# Reactantes: Al^{3} + Cu^{1}
# Productos: Al^{1} + Cu^{3}
#
# Semirreacciones de oxidación y reducción:
# reducción: Al^{3} + e- -> Al^{1}
# reducción: Cu^{1} + e- -> Cu^{3}
