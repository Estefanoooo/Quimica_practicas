# %% [markdown]
# <a href="https://colab.research.google.com/github/Estefanoooo/Quimica_practicas/blob/main/QUIMICA_PC8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### PROBLEMA 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install drawdata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 9.2 MB/s eta 0:00:00
# ...

# %%
from drawdata import draw_line, draw_scatter, draw_histogram

# %%
#A) Ley de Boyle: P vs 1/V
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
puntos = pd.read_csv("data(1).csv")
puntos
# Out:
#               x           y  z
# 0     68.453561  124.682955  a
# 1     27.342654  122.803539  a
# 2    117.991273  135.557668  a
# 3     70.528390  143.593540  a
# 4    107.731051   96.161374  a
# ..          ...         ... ..
# 189  305.368144  259.481596  a
# 190  161.689101  160.031753  a
# 191  179.749959  188.841873  a
# 192  178.597855  190.187573  a
# 193  166.887345  232.381151  a
#
# [194 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

df = pd.read_csv("data(1).csv")

x = df["x"].values.reshape(-1, 1)
y = df["y"].values

reg = LinearRegression()
reg.fit(x, y)

m = reg.coef_[0] # Pendiente
b = reg.intercept_ # Ordenada en el origen

y_pred = reg.predict(x)

plt.scatter(x, y, color="blue", label="Datos")
plt.plot(x, y_pred, color="red", label="Regresión lineal")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
#B) Ley de Charles: T vs V
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
puntos1 = pd.read_csv("data(2).csv")
puntos1
# Out:
#               x           y  z
# 0    620.258328  425.428633  a
# 1    596.417457  432.334076  a
# 2    567.652255  455.979815  a
# 3    530.956426  405.910591  a
# 4    531.494856  379.291248  a
# ..          ...         ... ..
# 335  357.428213  301.648751  a
# 336  308.123003  277.201333  a
# 337  362.499769  259.327659  a
# 338  383.916872  253.560771  a
# 339  355.153880  237.764861  a
#
# [340 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

df = pd.read_csv("data(2).csv")

x = df["x"].values.reshape(-1, 1)
y = df["y"].values

reg = LinearRegression()
reg.fit(x, y)

m = reg.coef_[0] # Pendiente
b = reg.intercept_ # Ordenada en el origen

y_pred = reg.predict(x)

plt.scatter(x, y, color="blue", label="Datos")
plt.plot(x, y_pred, color="red", label="Regresión lineal")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
#C) Ley de Gay Lussac: T vs P
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
puntos3 = pd.read_csv("lussac.csv")
puntos3
# Out:
#               x           y  z
# 0     47.893789  161.315805  a
# 1    128.954345  167.442645  a
# 2    145.802712  154.333188  a
# 3    143.446246  180.439109  a
# 4     80.389651  184.897087  a
# ..          ...         ... ..
# 244  656.495723  418.745622  a
# 245  619.513816  370.135688  a
# 246  639.911612  384.952570  a
# 247  582.766371  400.754838  a
# 248  603.997991  395.516720  a
#
# [249 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

df = pd.read_csv("lussac.csv")

x = df["x"].values.reshape(-1, 1)
y = df["y"].values

reg = LinearRegression()
reg.fit(x, y)

m = reg.coef_[0] # Pendiente
b = reg.intercept_ # Ordenada en el origen

y_pred = reg.predict(x)

plt.scatter(x, y, color="blue", label="Datos")
plt.plot(x, y_pred, color="red", label="Regresión lineal")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
#D) Ley de Boyle: VELOCIDAD vs #MOLECULAS
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
puntos4 = pd.read_csv("VM.csv")
puntos4
# Out:
#         x      y  z
# 0   0.000  0.258  a
# 1   0.025  0.274  a
# 2   0.050  0.314  a
# 3   0.075  0.330  a
# 4   0.100  0.358  a
# 5   0.125  0.392  a
# 6   0.150  0.416  a
# 7   0.175  0.446  a
# 8   0.200  0.460  a
# 9   0.225  0.494  a
# 10  0.250  0.520  a
# 11  0.275  0.542  a
# 12  0.300  0.564  a
# 13  0.325  0.582  a
# 14  0.350  0.594  a
# 15  0.375  0.602  a
# 16  0.400  0.610  a
# 17  0.425  0.614  a
# 18  0.450  0.616  a
# 19  0.475  0.616  a
# 20  0.500  0.616  a
# 21  0.525  0.612  a
# 22  0.550  0.608  a
# 23  0.575  0.600  a
# 24  0.600  0.578  a
# 25  0.625  0.558  a
# 26  0.650  0.544  a
# 27  0.675  0.524  a
# 28  0.700  0.488  a
# 29  0.725  0.444  a
# 30  0.750  0.390  a
# 31  0.775  0.330  a
# 32  0.800  0.294  a
# 33  0.825  0.260  a
# 34  0.850  0.222  a
# 35  0.875  0.196  a
# 36  0.900  0.164  a
# 37  0.925  0.156  a
# 38  0.950  0.140  a
# 39  0.975  0.124  a

# %% [markdown]
# ### PROBLEMA **2**

# %%
url="https://es.wikipedia.org/wiki/Tabla_peri%C3%B3dica_de_los_elementos"
tablas = pd.read_html(url)

# %%
tablas[10]
# Out:
#      Elemento Símbolo  Grupo  Período  Átomo  Masa  Protones  Neutrones  \
# 0   Hidrógeno       H      1        1      1     1         1          0
# 1   Nitrógeno       N     15        2      7    14         7          7
# 2     Oxígeno       O     16        2      8    16         8          8
# 3       Flúor       F     17        2      9    19         9         10
# 4       Cloro      Cl     17        3     17    35        17         19
# 5       Helio      He     18        1      2     4         2          2
# 6        Neón      Ne     18        2     10    20        10         10
# 7       Argón      Ar     18        3     18    40        18         22
# 8     Kriptón      Kr     18        4     36    84        36         48
# 9       Xenón      Xe     18        5     54   131        54         77
# 10      Radón      Rn     18        6     86   222        86        136
#
#     Electrones
# 0            1
# 1            7
# 2            8
# 3            9
# 4           17
# ...

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
plt.bar(tablas[10]['Elemento'],tablas[10]['Masa'])
# Out:
# <BarContainer object of 11 artists>
